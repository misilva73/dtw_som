# %%
import os
import pandas as pd

# %%
ucr_data_folder = os.path.abspath("../../data-ucr-archive")
file = os.path.join(ucr_data_folder, "DataSummary.csv")
data_df = pd.read_csv(file)
data_df.head()
# Out:
#    ID     Type         Name  Train   Test   Class Length  ED (w=0)  \
# 0   1    Image        Adiac     390    391     37    176    0.3887
# 1   2    Image    ArrowHead      36    175      3    251    0.2000
# 2   3  Spectro         Beef      30     30      5    470    0.3333
# 3   4    Image    BeetleFly      20     20      2    512    0.2500
# 4   5    Image  BirdChicken      20     20      2    512    0.4500
#
#   DTW (learned_w)   DTW (w=100)  Default rate         Data donor/editor
# 0       0.3913 (3)       0.3964        0.9591                  A. Jalba
# 1       0.2000 (0)       0.2971        0.6057          L. Ye & E. Keogh
# 2       0.3333 (0)       0.3667        0.8000  K. Kemsley &  A. Bagnall
# 3       0.3000 (7)       0.3000        0.5000     J. Hills & A. Bagnall
# 4       0.3000 (6)       0.2500        0.5000     J. Hills & A. Bagnall

# %%
data_df[data_df["Type"]=="Motion"]
# Out:
#       ID    Type                      Name  Train   Test   Class Length  \
# 11    12  Motion                  CricketX     390    390     12    300
# 12    13  Motion                  CricketY     390    390     12    300
# 13    14  Motion                  CricketZ     390    390     12    300
# 30    31  Motion                  GunPoint      50    150      2    150
# 33    34  Motion                   Haptics     155    308      5   1092
# 35    36  Motion               InlineSkate     100    550      7   1882
# 70    71  Motion          ToeSegmentation1      40    228      2    277
# 71    72  Motion          ToeSegmentation2      36    130      2    343
# 75    76  Motion    UWaveGestureLibraryAll     896   3582      8    945
# 76    77  Motion      UWaveGestureLibraryX     896   3582      8    315
# 77    78  Motion      UWaveGestureLibraryY     896   3582      8    315
# 78    79  Motion      UWaveGestureLibraryZ     896   3582      8    315
# 82    83  Motion                     Worms     181     77      5    900
# 83    84  Motion             WormsTwoClass     181     77      2    900
# 106  107  Motion           GunPointAgeSpan     135    316      2    150
# 107  108  Motion  GunPointMaleVersusFemale     135    316      2    150
# 108  109  Motion    GunPointOldVersusYoung     136    315      2    150
#
#      ED (w=0) DTW (learned_w)   DTW (w=100)  Default rate  \
# 11     0.4231      0.2282 (10)       0.2462        0.8974
# 12     0.4333      0.2410 (17)       0.2564        0.9051
# 13     0.4128       0.2538 (5)       0.2462        0.8974
# 30     0.0867      0.0867 (0)        0.0933        0.4933
# 33     0.6299       0.5877 (2)       0.6234        0.7825
# 35     0.6582      0.6127 (14)       0.6164        0.8164
# 70     0.3202       0.2500 (8)       0.2281        0.4737
# 71     0.1923       0.0923 (5)       0.1615        0.1846
# 75     0.0519       0.0343 (4)       0.1083        0.8716
# 76     0.2607       0.2267 (4)       0.2725        0.8716
# 77     0.3384       0.3009 (4)       0.3660        0.8716
# 78     0.3504       0.3222 (6)       0.3417        0.8716
# 82     0.5455       0.4675 (9)       0.4156        0.5714
# 83     0.3896       0.4156 (7)       0.3766        0.4286
# 106    0.1013       0.0348 (3)       0.0823        0.4937
# 107    0.0253       0.0253 (0)       0.0032        0.4747
# 108    0.0476       0.0349 (4)       0.1619        0.4762
#
#                 Data donor/editor
# 11            A. Mueen & E. Keogh
# 12            A. Mueen & E. Keogh
# 13            A. Mueen & E. Keogh
# 30   A. Ratanamahatana & E. Keogh
# 33                       J. Brady
# 35           F. Morchen & O. Hoos
# 70   A. Bagnall, L. Ye & E. Keogh
# 71   A. Bagnall, L. Ye & E. Keogh
# 75            A. Bagnall & J. Liu
# 76                         J. Liu
# 77                         J. Liu
# 78                         J. Liu
# 82                     A. Bagnall
# 83                     A. Bagnall
# 106  A. Ratanamahatana & E. Keogh
# 107  A. Ratanamahatana & E. Keogh
# 108  A. Ratanamahatana & E. Keogh

# %%
data_df[data_df["Class"]>10]
# Out:
#       ID          Type                        Name  Train   Test   Class  \
# 0      1         Image                       Adiac     390    391     37
# 11    12        Motion                    CricketX     390    390     12
# 12    13        Motion                    CricketY     390    390     12
# 13    14        Motion                    CricketZ     390    390     12
# 23    24         Image                     FaceAll     560   1690     14
# 25    26         Image                    FacesUCR     200   2050     14
# 26    27         Image                  FiftyWords     450    455     50
# 36    37        Sensor         InsectWingbeatSound     220   1980     11
# 48    49           ECG  NonInvasiveFetalECGThorax1    1800   1965     42
# 49    50           ECG  NonInvasiveFetalECGThorax2    1800   1965     42
# 53    54        Sensor                     Phoneme     214   1896     39
# 61    62         Image                   ShapesAll     600    600     60
# 67    68         Image                 SwedishLeaf     500    625     15
# 81    82         Image                WordSynonyms     267    638     25
# 91    92         Image                        Crop    7200  16800     24
# 95    96           EOG         EOGHorizontalSignal     362    362     12
# 96    97           EOG           EOGVerticalSignal     362    362     12
# 100  101           HRM                       Fungi      18    186     18
# 101  102    Trajectory             GestureMidAirD1     208    130     26
# 102  103    Trajectory             GestureMidAirD2     208    130     26
# 103  104    Trajectory             GestureMidAirD3     208    130     26
# 116  117  Hemodynamics           PigAirwayPressure     104    208     52
# 117  118  Hemodynamics              PigArtPressure     104    208     52
# 118  119  Hemodynamics                      PigCVP     104    208     52
# 119  120        Device                       PLAID     537    537     11
#
#     Length  ED (w=0) DTW (learned_w)   DTW (w=100)  Default rate  \
# 0      176    0.3887       0.3913 (3)       0.3964        0.9591
# 11     300    0.4231      0.2282 (10)       0.2462        0.8974
# 12     300    0.4333      0.2410 (17)       0.2564        0.9051
# 13     300    0.4128       0.2538 (5)       0.2462        0.8974
# 23     131    0.2864       0.1917 (3)       0.1923        0.8302
# 25     131    0.2307      0.0878 (12)       0.0951        0.8566
# 26     270    0.3692       0.2418 (6)       0.3099        0.8747
# 36     256    0.4384       0.4152 (1)       0.6449        0.9091
# 48     750    0.1710       0.1893 (1)       0.2097        0.9705
# 49     750    0.1201       0.1290 (1)       0.1354        0.9705
# 53    1024    0.8908      0.7727 (14)       0.7716        0.8871
# 61     512    0.2483       0.1980 (4)       0.2317        0.9833
# 67     128    0.2112       0.1536 (2)       0.2080        0.9216
# 81     270    0.3824       0.2618 (9)       0.3511        0.7806
# 91      46    0.2883       0.2883 (0)       0.3348        0.9583
# 95    1250    0.5829       0.5249 (1)       0.4972        0.9144
# 96    1250    0.5580       0.5249 (2)       0.5525        0.9144
# 100    201    0.1774       0.1774 (0)       0.1613        0.8978
# 101   Vary    0.4231       0.3615 (5)       0.4308        0.9615
# 102   Vary    0.5077       0.4000 (6)       0.3923        0.9615
# 103   Vary    0.6538       0.6231 (1)       0.6769        0.9615
# 116   2000    0.9423       0.9038 (1)       0.8942        0.9808
# 117   2000    0.8750       0.8029 (1)       0.7548        0.9808
# 118   2000    0.9183      0.8413 (11)       0.8462        0.9808
# 119   Vary    0.4767      0.1657 (12)       0.1639        0.8380
#
#                    Data donor/editor
# 0                           A. Jalba
# 11               A. Mueen & E. Keogh
# 12               A. Mueen & E. Keogh
# 13               A. Mueen & E. Keogh
# 23                  X. Xi & E. Keogh
# 25                  X. Xi & E. Keogh
# 26             T. Rath & R. Manmatha
# 36                Y. Chen & E. Keogh
# 48   physionet.org, B. Hu & E. Keogh
# 49   physionet.org, B. Hu & E. Keogh
# 53             H. Hamooni & A. Mueen
# 61             J. Hills & A. Bagnall
# 67                     O. Soderkvist
# 81             T. Rath & R. Manmatha
# 91                      F. Petitjean
# 95              E. Keogh & H. A. Dau
# 96              E. Keogh & H. A. Dau
# 100                         W. Fonzi
# 101                        H. A. Dau
# 102                        H. A. Dau
# 103                        H. A. Dau
# 116                 M. Guillame-Bert
# 117                 M. Guillame-Bert
# 118                 M. Guillame-Bert
# 119                       P. Schafer

# %%
import numpy as np
from scipy.io import loadmat  # this is the SciPy module that loads mat-files
import matplotlib.pyplot as plt
from datetime import datetime, date, time
import pandas as pd

mat = loadmat('measured_data.mat')  # load mat-file
mdata = mat['measuredData']  # variable in mat file
mdtype = mdata.dtype  # dtypes of structures are "unsized objects"
# * SciPy reads in structures as structured NumPy arrays of dtype object
# * The size of the array is the size of the structure array, not the number
#   elements in any particular field. The shape defaults to 2-dimensional.
# * For convenience make a dictionary of the data using the names from dtypes
# * Since the structure has only one element, but is 2-D, index it at [0, 0]
ndata = {n: mdata[n][0, 0] for n in mdtype.names}
# Reconstruct the columns of the data table from just the time series
# Use the number of intervals to test if a field is a column or metadata
columns = [n for n, v in ndata.iteritems() if v.size == ndata['numIntervals']]
# now make a data frame, setting the time stamps as the index
df = pd.DataFrame(np.concatenate([ndata[c] for c in columns], axis=1),
                  index=[datetime(*ts) for ts in ndata['timestamps']],
                  columns=columns)
